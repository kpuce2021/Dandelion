# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from PIL import Image
import glob

# %%
img = Image.open('/root/Dandelion/Dataset_append/Pepero_Original/Pepero_Original_0_1015.jpg')
plt.imshow(img)

# %%
plt.imshow(img.resize([64,64]))

# %%
data = img.convert("RGB")

# %%
data = data.resize([64,64])

# %%
data = np.asarray(data)

# %%
data.reshape([1, 64, 64, 3])
# Out:
# array([[[[149, 139, 117],
#          [166, 156, 136],
#          [177, 167, 149],
#          ...,
#          [147, 143, 136],
#          [147, 144, 136],
#          [147, 144, 136]],
#
#         [[148, 137, 115],
#          [164, 155, 134],
#          [176, 166, 147],
#          ...,
#          [149, 148, 139],
#          [150, 149, 140],
#          [151, 150, 141]],
#
#         [[146, 134, 114],
#          [163, 153, 133],
#          [175, 165, 147],
#          ...,
#          [155, 153, 146],
#          [156, 153, 147],
#          [157, 154, 147]],
#
#         ...,
#
#         [[189, 178, 154],
#          [188, 177, 154],
#          [188, 177, 154],
#          ...,
#          [203, 201, 192],
#          [200, 200, 192],
#          [205, 203, 195]],
#
#         [[188, 175, 154],
#          [189, 175, 155],
#          [190, 175, 155],
#          ...,
#          [203, 200, 191],
#          [200, 200, 192],
#          [204, 203, 194]],
#
#         [[192, 176, 156],
#          [192, 176, 155],
#          [191, 176, 155],
#          ...,
#          [202, 200, 191],
#          [200, 199, 192],
#          [204, 203, 193]]]], dtype=uint8)

# %%
data.shape
# Out:
# (64, 64, 3)

# %%
# !pip install yapf
